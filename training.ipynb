# %%
import sys, os
from pathlib import Path
from unittest.mock import patch

os.chdir(Path.home() / "CS668 Final Project/LoL-Clip-Pipeline")
sys.path.insert(0, str(Path.home() / "CS668 Final Project/LoL-Clip-Pipeline"))
os.environ.setdefault("HF_HOME",
    str(Path.home() / ".cache" / "huggingface"))

# Patch reconfigure so it does nothing in notebook environment
import io
if not hasattr(sys.stdout, 'reconfigure'):
    sys.stdout.reconfigure = lambda **kwargs: None
if not hasattr(sys.stderr, 'reconfigure'):
    sys.stderr.reconfigure = lambda **kwargs: None

from backend import trainer_worker

sys.argv = [
    "trainer_worker.py",
    "--slice", "0",
    "--run-id", "notebook_run_001",
    "--clips-dir", str(Path.home() / "training_clips"),
    "--labels", "data/trainer_labels_all.json",
    "--epochs", "25",
    "--output-dir", "checkpoints",
]

exit_code = trainer_worker.main()
print(f"Training finished with exit code: {exit_code}")
